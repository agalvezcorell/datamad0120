# %% [markdown]
# ## Conexiones

# %%
import sqlalchemy as db
from getpass import getpass
import pandas as pd

# %%
password = getpass("Mysql Password: ")
# Out:
# Mysql Password: ········

# %%
dbName = "publications"
connectionData = f"mysql+pymysql://root:{password}@localhost/{dbName}"

# %%
engine = db.create_engine(connectionData)
print("Connected to server!")
# Out:
# Connected to server!

# %% [markdown]
# ## Challenge 1

# %%
#YO
pd.read_sql_query("""
SELECT titleauthor.au_id, titleauthor.title_id, titleauthor.royaltyper, 
titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100 as sales_royalty
	FROM titleauthor
    
    INNER JOIN publications.titles
    ON titleauthor.title_id = titles.title_id
    INNER JOIN publications.sales
    ON sales.title_id = titleauthor.title_id
""",engine)
# Out:
#           au_id title_id  royaltyper  sales_royalty
# 0   213-46-8915   BU1032          40          3.998
# 1   409-56-7008   BU1032          60          5.997
# 2   899-46-2035   PS2091          50          1.971
# 3   998-72-3567   PS2091          50          1.971
# 4   427-17-2319   PC8888          50         50.000
# 5   846-92-7186   PC8888          50         50.000
# 6   899-46-2035   PS2091          50         49.275
# 7   998-72-3567   PS2091          50         49.275
# 8   899-46-2035   PS2091          50          6.570
# 9   998-72-3567   PS2091          50          6.570
# 10  807-91-6654   TC3218         100         83.800
# 11  648-92-1872   TC4203         100         33.460
# 12  267-41-2394   TC7777          30          8.994
# 13  472-27-2349   TC7777          30          8.994
# 14  672-71-3249   TC7777          40         11.992
# 15  899-46-2035   PS2091          50         13.140
# 16  998-72-3567   PS2091          50         13.140
# 17  722-51-5454   MC3021          75         13.455
# 18  899-46-2035   MC3021          25          4.485
# 19  724-80-9391   PS1372          25         10.795
# 20  756-30-7391   PS1372          75         32.385
# 21  998-72-3567   PS2106         100         17.500
# 22  172-32-1176   PS3333         100         29.985
# 23  486-29-1786   PS7777         100         19.975
# 24  274-80-9391   BU7832         100         29.985
# 25  712-45-1867   MC2222         100         23.988
# 26  213-46-8915   BU2075         100         25.116
# 27  722-51-5454   MC3021          75          8.073
# 28  899-46-2035   MC3021          25          2.691
# 29  213-46-8915   BU1032          40          7.996
# 30  409-56-7008   BU1032          60         11.994
# 31  267-41-2394   BU1111          40         11.950
# 32  724-80-9391   BU1111          60         17.925
# 33  238-95-7766   PC1035         100        110.160

# %%
#DAV
pd.read_sql_query(
"""
  
   SELECT 
    authors.au_id AS 'AUTHOR ID',
    authors.au_fname AS 'FIRST NAME',
    authors.au_lname AS 'LAST NAME',
    SUM(sales.qty*titles.price*titleauthor.royaltyper/100*titles.royalty / 100) as 'PROFIT'

FROM authors
    INNER JOIN titleauthor ON authors.au_id=titleauthor.au_id
    INNER JOIN titles ON titles.title_id=titleauthor.title_id
    INNER JOIN sales on titleauthor.title_id=sales.title_id
        
GROUP BY authors.au_id, authors.au_id
ORDER BY PROFIT DESC

""",engine)
# Out:
#       AUTHOR ID FIRST NAME       LAST NAME   PROFIT
# 0   238-95-7766     Cheryl          Carson  110.160
# 1   998-72-3567     Albert          Ringer   88.456
# 2   807-91-6654     Sylvia        Panteley   83.800
# 3   899-46-2035       Anne          Ringer   78.132
# 4   427-17-2319        Ann            Dull   50.000
# 5   846-92-7186     Sheryl          Hunter   50.000
# 6   213-46-8915   Marjorie           Green   37.110
# 7   648-92-1872   Reginald  Blotchet-Halls   33.460
# 8   756-30-7391      Livia          Karsen   32.385
# 9   172-32-1176    Johnson           White   29.985
# 10  274-80-9391       Dean        Straight   29.985
# 11  724-80-9391    Stearns      MacFeather   28.720
# 12  712-45-1867      Innes    del Castillo   23.988
# 13  722-51-5454     Michel        DeFrance   21.528
# 14  267-41-2394    Michael         O'Leary   20.944
# 15  486-29-1786   Charlene        Locksley   19.975
# 16  409-56-7008    Abraham          Bennet   17.991
# 17  672-71-3249      Akiko        Yokomoto   11.992
# 18  472-27-2349       Burt      Gringlesby    8.994

# %% [markdown]
# ## Challenge 2

# %%
#YO

# %%
#DAV

# %%
df = pd.read_sql_query("SELECT AuthorID, sum(Royalty)+t.advance as PROFIT FROM SELECT TitleID, AuthorID, sum(Royalty) as Royalty2 FROM SELECT t.title_id as TitleID,ta.au_id as AuthorID,concat(round(t.price * s.qty * t.royalty / 100 * ta.royaltyper / 100,2)) as Royalty FROM titleauthor as ta INNER JOIN titles as t ON t.title_id=ta.title_id INNER JOIN sales as s ON t.title_id=s.title_id as calc GROUP BY TitleID,AuthorID ORDER BY Royalty DESC as royal INNER JOIN titles as t TitleID=t.title_id, GROUP BY AuthorID ORDER BY PROFIT DESC LIMIT 3;",engine)
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1283                     self.dialect.do_execute(
# -> 1284                         cursor, statement, parameters, context
#    1285                     )
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# /usr/local/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# /usr/local/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'SELECT TitleID, AuthorID, sum(Royalty) as Royalty2 FROM SELECT t.title_id as Tit' at line 1")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-16-ca039d92cf10> in <module>
# ----> 1 df = pd.read_sql_query("SELECT AuthorID, sum(Royalty)+t.advance as PROFIT FROM SELECT TitleID, AuthorID, sum(Royalty) as Royalty2 FROM SELECT t.title_id as TitleID,ta.au_id as AuthorID,concat(round(t.price * s.qty * t.royalty / 100 * ta.royaltyper / 100,2)) as Royalty FROM titleauthor as ta INNER JOIN titles as t ON t.title_id=ta.title_id INNER JOIN sales as s ON t.title_id=s.title_id as calc GROUP BY TitleID,AuthorID ORDER BY Royalty DESC as royal INNER JOIN titles as t TitleID=t.title_id, GROUP BY AuthorID ORDER BY PROFIT DESC LIMIT 3;",engine)
#       2 df
#
# /usr/local/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# /usr/local/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# /usr/local/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2242
#    2243         connection = self._contextual_connect(close_with_result=True)
# -> 2244         return connection.execute(statement, *multiparams, **params)
#    2245
#    2246     def scalar(self, statement, *multiparams, **params):
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1010         """
#    1011         if isinstance(object_, util.string_types[0]):
# -> 1012             return self._execute_text(object_, multiparams, params)
#    1013         try:
#    1014             meth = object_._execute_on_connection
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1185             parameters,
#    1186             statement,
# -> 1187             parameters,
#    1188         )
#    1189         if self._has_events or self.engine._has_events:
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1322         except BaseException as e:
#    1323             self._handle_dbapi_exception(
# -> 1324                 e, statement, parameters, cursor, context
#    1325             )
#    1326
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1516             elif should_wrap:
#    1517                 util.raise_(
# -> 1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#    1520             else:
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1282                 if not evt_handled:
#    1283                     self.dialect.do_execute(
# -> 1284                         cursor, statement, parameters, context
#    1285                     )
#    1286
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     588
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#     592     def do_execute_no_params(self, cursor, statement, context=None):
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# /usr/local/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# /usr/local/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'SELECT TitleID, AuthorID, sum(Royalty) as Royalty2 FROM SELECT t.title_id as Tit' at line 1")
# [SQL: SELECT AuthorID, sum(Royalty)+t.advance as PROFIT FROM SELECT TitleID, AuthorID, sum(Royalty) as Royalty2 FROM SELECT t.title_id as TitleID,ta.au_id as AuthorID,concat(round(t.price * s.qty * t.royalty / 100 * ta.royaltyper / 100,2)) as Royalty FROM titleauthor as ta INNER JOIN titles as t ON t.title_id=ta.title_id INNER JOIN sales as s ON t.title_id=s.title_id as calc GROUP BY TitleID,AuthorID ORDER BY Royalty DESC as royal INNER JOIN titles as t TitleID=t.title_id, GROUP BY AuthorID ORDER BY PROFIT DESC LIMIT 3;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
df = pd.read_sql_query("""
CREATE temporary TABLE FirstTable
(Select authors.au_id,
titles.title_id, 
(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100) AS sales_royalty 
from titles
LEFT JOIN titleauthor ON titleauthor.title_id = titles.title_id 
LEFT JOIN authors ON authors.au_id = titleauthor.au_id
LEFT JOIN sales ON sales.title_id = titles.title_id);

Create temporary table SecondTable(Select title_id Title_ID, au_id Author_ID, SUM(Sales_royalty) 
FROM FirstTable group by au_id, title_id);


Select Author_ID, titles.advance, titles.royalty 
FROM SecondTable
LEFT JOIN titles
 ON titles.title_id = SecondTable.title_id 
 group by Author_ID, advance, royalty;
""", engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1283                     self.dialect.do_execute(
# -> 1284                         cursor, statement, parameters, context
#    1285                     )
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# /usr/local/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# /usr/local/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'Create temporary table SecondTable(Select title_id Title_ID, au_id Author_ID, SU' at line 10")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-18-fbd3d8d7a587> in <module>
#      18  ON titles.title_id = SecondTable.title_id
#      19  group by Author_ID, advance, royalty;
# ---> 20 """, engine)
#
# /usr/local/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# /usr/local/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# /usr/local/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2242
#    2243         connection = self._contextual_connect(close_with_result=True)
# -> 2244         return connection.execute(statement, *multiparams, **params)
#    2245
#    2246     def scalar(self, statement, *multiparams, **params):
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1010         """
#    1011         if isinstance(object_, util.string_types[0]):
# -> 1012             return self._execute_text(object_, multiparams, params)
#    1013         try:
#    1014             meth = object_._execute_on_connection
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1185             parameters,
#    1186             statement,
# -> 1187             parameters,
#    1188         )
#    1189         if self._has_events or self.engine._has_events:
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1322         except BaseException as e:
#    1323             self._handle_dbapi_exception(
# -> 1324                 e, statement, parameters, cursor, context
#    1325             )
#    1326
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1516             elif should_wrap:
#    1517                 util.raise_(
# -> 1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#    1520             else:
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1282                 if not evt_handled:
#    1283                     self.dialect.do_execute(
# -> 1284                         cursor, statement, parameters, context
#    1285                     )
#    1286
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     588
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#     592     def do_execute_no_params(self, cursor, statement, context=None):
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# /usr/local/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# /usr/local/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'Create temporary table SecondTable(Select title_id Title_ID, au_id Author_ID, SU' at line 10")
# [SQL:
# CREATE temporary TABLE FirstTable
# (Select authors.au_id,
# titles.title_id,
# (titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100) AS sales_royalty
# from titles
# LEFT JOIN titleauthor ON titleauthor.title_id = titles.title_id
# LEFT JOIN authors ON authors.au_id = titleauthor.au_id
# LEFT JOIN sales ON sales.title_id = titles.title_id);
#
# Create temporary table SecondTable(Select title_id Title_ID, au_id Author_ID, SUM(Sales_royalty)
# FROM FirstTable group by au_id, title_id);
#
#
# Select Author_ID, titles.advance, titles.royalty
# FROM SecondTable
# LEFT JOIN titles
#  ON titles.title_id = SecondTable.title_id
#  group by Author_ID, advance, royalty;
# ]
# (Background on this error at: http://sqlalche.me/e/f405)
